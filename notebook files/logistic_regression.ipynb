# %%
from data_loader import load_dataset1, load_dataset2
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler

# %%
#load and pre-process data
#mild imbalance in classes but should be fine
x1, y1 = load_dataset1()
x2, y2 = load_dataset2()
scalar = StandardScaler(copy=False)
scalar.fit(x1)
scalar.transform(x1)
scalar.fit(x2)

#binary var
scalar.mean_[4] = 0
scalar.var_[4] = 1
scalar.scale_[4] = 1
scalar.transform(x2)

#generate train and test split - NOTE: we do not use our test split at all until we have decided that we have our best model (which we will decide based on the validation
# loss)
train_x1, test_x1, train_y1, test_y1 = train_test_split(x1,y1, test_size=.2, random_state=42)
train_x2, test_x2, train_y2, test_y2 = train_test_split(x2,y2,test_size=.2, random_state=42)

# %%
# define params, model, and grid search
params = {
  "C": np.logspace(-5,6,12),
  "penalty": ("l2","l1", "elasticnet", None),
  "solver": ('lbfgs', 'liblinear', 'newton-cg', 'newton-cholesky', 'sag', 'saga')
}
clf_1 = LogisticRegression(random_state=42, max_iter=15000)
clf_2 = LogisticRegression(random_state=42, max_iter=15000,tol = 1e-10)
grid_search_1 = GridSearchCV(clf_1,params, cv=10, scoring=('accuracy','f1','precision', 'recall', 'roc_auc'), refit=False, verbose=2, n_jobs=-1, error_score=-1)
grid_search_2 = GridSearchCV(clf_2,params, cv=10, scoring=('accuracy','f1','precision', 'recall', 'roc_auc'), refit=False, verbose=2, n_jobs=-1, error_score=-1)

# %%
#run grid search, write results to csv file
#grid_search_1.fit(train_x1, train_y1)
#df = pd.DataFrame(grid_search_1.cv_results_)
#df.to_csv('./results/logistic_regression_grid_search_data_set1.csv')

grid_search_2.fit(train_x2, train_y2)
df = pd.DataFrame(grid_search_2.cv_results_)
df.to_csv('./results/logistic_regression_grid_search_data_set2.csv')
# Out:
# Fitting 10 folds for each of 288 candidates, totalling 2880 fits
# c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py:425: FitFailedWarning:
# 1320 fits failed out of a total of 2880.
# The score on these train-test partitions for these parameters will be set to -1.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got l1 penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver lbfgs supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 66, in _check_solver
#     raise ValueError(
# ValueError: Only 'saga' solver supports elasticnet penalty, got solver=liblinear.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cg supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver newton-cholesky supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1169, in fit
#     solver = _check_solver(self.solver, self.penalty, self.dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 56, in _check_solver
#     raise ValueError(
# ValueError: Solver sag supports only 'l2' or 'none' penalties, got elasticnet penalty.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1179, in fit
#     raise ValueError("l1_ratio must be specified when penalty is elasticnet.")
# ValueError: l1_ratio must be specified when penalty is elasticnet.
#
# --------------------------------------------------------------------------------
# 120 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\model_selection\_validation.py", line 729, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\base.py", line 1152, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\linear_model\_logistic.py", line 1228, in fit
#     self.coef_, self.intercept_, self.n_iter_ = _fit_liblinear(
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\svm\_base.py", line 1229, in _fit_liblinear
#     solver_type = _get_liblinear_solver_type(multi_class, penalty, loss, dual)
#   File "c:\Users\Benjamin\OneDrive - University of Virginia\Third Year\CS 6336- Machine Learning\final project\CS6336\.venv\lib\site-packages\sklearn\svm\_base.py", line 1060, in _get_liblinear_solver_type
#     raise ValueError(
# ValueError: Unsupported set of arguments: The combination of penalty='None' and loss='logistic_regression' is not supported, Parameters: penalty=None, loss='logistic_regression', dual=False
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
